# %%
import pandas as pd

df = pd.read_csv("BMW sales data (2010-2024) (1).csv")

# %%
df.head()
# Out:
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# 4      122131      49898          3080                  Low

# %%
df.shape
# Out:
# (50000, 11)

# %%
df.dtypes
# Out:
# Model                    object
# Year                      int64
# Region                   object
# Color                    object
# Fuel_Type                object
# Transmission             object
# Engine_Size_L           float64
# Mileage_KM                int64
# Price_USD                 int64
# Sales_Volume              int64
# Sales_Classification     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Model                   0
# Year                    0
# Region                  0
# Color                   0
# Fuel_Type               0
# Transmission            0
# Engine_Size_L           0
# Mileage_KM              0
# Price_USD               0
# Sales_Volume            0
# Sales_Classification    0
# dtype: int64

# %% [markdown]
# There are no Null values in this dataset

# %% [markdown]
# since there are no NULL values, it is not necessary to drop and fill the null values

# %%
df["Mileage_KM"] = df["Mileage_KM"].astype(float)

# %%
df = pd.get_dummies(df, drop_first=True)

# %% [markdown]
# Converting the categorical value into numerical value by droping one dummy coloumn to avoid multicollinearity

# %%
df.head()
# Out:
#    Year  Engine_Size_L  Mileage_KM  Price_USD  Sales_Volume  Model_5 Series  \
# 0  2016            3.5    151748.0      98740          8300            True
# 1  2013            1.6    121671.0      79219          3428           False
# 2  2022            4.5     10991.0     113265          6994            True
# 3  2024            1.7     27255.0      60971          4047           False
# 4  2020            2.1    122131.0      49898          3080           False
#
#    Model_7 Series  Model_M3  Model_M5  Model_X1  ...  Color_Blue  Color_Grey  \
# 0           False     False     False     False  ...       False       False
# 1           False     False     False     False  ...       False       False
# 2           False     False     False     False  ...        True       False
# 3           False     False     False     False  ...        True       False
# 4            True     False     False     False  ...       False       False
#
# ...

# %%
import seaborn as sns
import matplotlib.pylab as plt

sns.boxplot(x=df["Sales_Volume"])
plt.show()
